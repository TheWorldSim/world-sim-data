# %%
import importlib
import os
import sys

current_directory = os.getcwd()
for path in [current_directory]:
    if path not in sys.path:
        sys.path.append(path)

import data.dgg.process as process
importlib.reload(process)

process.process()
